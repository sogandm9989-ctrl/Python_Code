# %%
numbers = []
for i in range(20):
    num = float(input(f"enter the number {i+1}:"))
    numbers.append(num)
    maximum = max(numbers)
    minimum = min(numbers)
    print("biggest number:", maximum)
    print("smallest number:", minimum)
# Out:
# biggest number: 75.0
# smallest number: 75.0
# biggest number: 75.0
# smallest number: 47.0
# biggest number: 75.0
# smallest number: 1.9

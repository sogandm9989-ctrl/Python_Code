# %%
hours = int(input("enter your hour:"))
minutes = int(input("enter your minutes:"))
seconds = int(input("enter your seconds:"))
total_seconds = (hours * 3600) + (minutes * 60) + seconds
print("total seconds:", total_seconds)
# Out:
# total seconds: 351973

# %%
a = int(input("enter your first number:"))
b = int(input("enter your second number:"))
start = min(a , b)
end = max(a , b)
product = 1
for i in range(start, end + 1):
    product *= i
    print("the product of the numbers between 'a' and 'b' is equal to:", product)
# Out:
# the product of the numbers between 'a' and 'b' is equal to: 6
# the product of the numbers between 'a' and 'b' is equal to: 42
# the product of the numbers between 'a' and 'b' is equal to: 336

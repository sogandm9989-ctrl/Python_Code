# %%
a = float(input("enter your first number:"))
b = float(input("enter your second number:"))
c = float(input("enter your third number:"))
if (a + b > c) and (a + c > b) and (b + c > a):
    print("a triangle can be drawn with these sides")
else:
    print("a triangle can not be drawn with these sides")
# Out:
# a triangle can be drawn with these sides

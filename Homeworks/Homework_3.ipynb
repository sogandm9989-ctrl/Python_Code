# %%
a = int(input("enter your first number:"))
b = int(input("enter your second number:"))
start = min(a , b)
end = max(a , b)
total = 0
for i in range(start, end + 1):
    total += i
    print("the sum of the numbers between 'a' and 'b' is equal to:", total)
# Out:
# the sum of the numbers between 'a' and 'b' is equal to: 4
# the sum of the numbers between 'a' and 'b' is equal to: 9
# the sum of the numbers between 'a' and 'b' is equal to: 15
# the sum of the numbers between 'a' and 'b' is equal to: 22
# the sum of the numbers between 'a' and 'b' is equal to: 30
